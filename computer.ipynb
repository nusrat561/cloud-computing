# %%
# print day according to its number let say monday number is 1 and so on.
 #day_number = int(input("enter day number"))

if day_number == 1:
    print("the day is monday")
elif day_number == 2:
    print("the day is tuesday")
elif day_number == 3:
    print("the day is wednesday")
elif day_number == 4:
    print("the day is thursday")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 # print day according to its number let say monday number is 1 and so on.
#       2  #day_number = int(input("enter day number"))
# ----> 4 if day_number == 1:
#       5     print("the day is monday")
#       6 elif day_number == 2:
#
# NameError: name 'day_number' is not defined
